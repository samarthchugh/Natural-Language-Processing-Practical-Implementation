# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
corpus="""
Hello , My name is Samarth Chugh.
I am a student of BCA at VIPS.
My hobbies are playing video games and listening to music."""

# %%
from nltk.tokenize import sent_tokenize
sentences=sent_tokenize(corpus)
print(sentences)
# Out:
# ['\nHello , My name is Samarth Chugh.', 'I am a student of BCA at VIPS.', 'My hobbies are playing video games and listening to music.']

# %%
from nltk.tokenize import word_tokenize
words=word_tokenize(corpus)
print(words)
# Out:
# ['Hello', ',', 'My', 'name', 'is', 'Samarth', 'Chugh', '.', 'I', 'am', 'a', 'student', 'of', 'BCA', 'at', 'VIPS', '.', 'My', 'hobbies', 'are', 'playing', 'video', 'games', 'and', 'listening', 'to', 'music', '.']

# %%
from nltk.tokenize import wordpunct_tokenize
corpus="""
Hello , My name is Samarth Chugh.
I am a student of BCA at VIPS.
My hobbies are playing video games and listening to music."""
words=wordpunct_tokenize(corpus)
print(words)
# Out:
# ['Hello', ',', 'My', 'name', 'is', 'Samarth', 'Chugh', '.', 'I', 'am', 'a', 'student', 'of', 'BCA', 'at', 'VIPS', '.', 'My', 'hobbies', 'are', 'playing', 'video', 'games', 'and', 'listening', 'to', 'music', '.']

# %%
from nltk.tokenize import TreebankWordDetokenizer
tokenizer=TreebankWordDetokenizer()
tokenizer.tokenize(corpus)
# Out:
# 'H e l l o  ,   M y   n a m e   i s   S a m a r t h   C h u g h . \n I   a m   a   s t u d e n t   o f   B C A   a t   V I P S . \n M y   h o b b i e s   a r e   p l a y i n g   v i d e o   g a m e s   a n d   l i s t e n i n g   t o   m u s i c.'

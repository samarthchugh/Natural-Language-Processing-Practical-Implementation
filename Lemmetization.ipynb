# %% [markdown]
# ### Wordnet Lemmetizer
# Lemmatization technique is like stemming. The output we will get after lemmatization is called ‘lemma’, which is a root word rather than root stem, the output of stemming. After lemmatization, we will be getting a valid word that means the same thing.
#
# NLTK provides WordNetLemmatizer class which is a thin wrapper around the wordnet corpus. This class uses morphy() function to the WordNet CorpusReader class to find a lemma. Let us understand it with an example −

# %%
## examples are Q&A , chatbots, text summarization
from nltk.stem import WordNetLemmatizer
lemmetizer=WordNetLemmatizer()

# %%
import nltk
nltk.download('wordnet')
lemmetizer.lemmatize('going')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# 'going'

# %%
'''
POS- Noun-n
verb-v
adjective-a
adverb-r
'''
lemmetizer.lemmatize('going',pos='v')
# Out:
# 'go'

# %%
words = ["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalize"]

# %%
for word in words:
  print(word+"----->"+lemmetizer.lemmatize(word,pos='v'))
# Out:
# eating----->eat
# eats----->eat
# eaten----->eat
# writing----->write
# writes----->write
# programming----->program
# programs----->program
# history----->history
# finally----->finally
# finalize----->finalize

# %%
lemmetizer.lemmatize('goes')
# Out:
# 'go'

# %%
lemmetizer.lemmatize('fairly','a'),lemmetizer.lemmatize('sportingly'),lemmetizer.lemmatize('ugliest','a')
# Out:
# ('fairly', 'sportingly', 'ugly')
